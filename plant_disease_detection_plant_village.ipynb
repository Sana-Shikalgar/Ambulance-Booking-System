# %% [markdown]
# <a href="https://colab.research.google.com/github/Sana-Shikalgar/Ambulance-Booking-System/blob/main/plant_disease_detection_plant_village.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Setting Up The System

# %%
# Changing the version in colab
# !python3 --version
# !sudo apt-get install python3.8

# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1

# Choose one of the given alternatives:
# !sudo update-alternatives --config python3

# !python3 --version
# Out:
# Python 3.11.11
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.8-minimal libpython3.8-stdlib python3.8-minimal
# Suggested packages:
#   python3.8-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.8-minimal libpython3.8-stdlib python3.8 python3.8-minimal
# 0 upgraded, 4 newly installed, 0 to remove and 49 not upgraded.
# Need to get 5,076 kB of archives.
# After this operation, 18.8 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.8-minimal amd64 3.8.20-1+jammy1 [796 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8-minimal amd64 3.8.20-1+jammy1 [2,023 kB]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.8-stdlib amd64 3.8.20-1+jammy1 [1,817 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8 amd64 3.8.20-1+jammy1 [440 kB]
# Fetched 5,076 kB in 12s (430 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpython3.8-minimal:amd64.
# (Reading database ... 124561 files and directories currently installed.)
# Preparing to unpack .../libpython3.8-minimal_3.8.20-1+jammy1_amd64.deb ...
# Unpacking libpython3.8-minimal:amd64 (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8-minimal.
# Preparing to unpack .../python3.8-minimal_3.8.20-1+jammy1_amd64.deb ...
# Unpacking python3.8-minimal (3.8.20-1+jammy1) ...
# Selecting previously unselected package libpython3.8-stdlib:amd64.
# Preparing to unpack .../libpython3.8-stdlib_3.8.20-1+jammy1_amd64.deb ...
# Unpacking libpython3.8-stdlib:amd64 (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8.
# Preparing to unpack .../python3.8_3.8.20-1+jammy1_amd64.deb ...
# Unpacking python3.8 (3.8.20-1+jammy1) ...
# Setting up libpython3.8-minimal:amd64 (3.8.20-1+jammy1) ...
# Setting up python3.8-minimal (3.8.20-1+jammy1) ...
# Setting up libpython3.8-stdlib:amd64 (3.8.20-1+jammy1) ...
# Setting up python3.8 (3.8.20-1+jammy1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# There are 3 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.11   2         auto mode
#   1            /usr/bin/python3.10   1         manual mode
#   2            /usr/bin/python3.11   2         manual mode
#   3            /usr/bin/python3.8    1         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 3
# update-alternatives: using /usr/bin/python3.8 to provide /usr/bin/python3 (python3) in manual mode
# Python 3.8.20

# %% [markdown]
# ### IMPORTING IMPORTANT LIBRARIES

# %%
# !python3 --version
# Out:
# Python 3.8.20

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import torch
from torchvision import datasets, transforms, models  # datsets  , transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn as nn
import torch.nn.functional as F
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# # Unzipping the datasets

# !unzip /content/drive/MyDrive/Plant-Disease/Dataset_02/data_without_aug.zip -d /content/drive/MyDrive/Plant-Disease/Dataset_02
# !unzip /content/drive/MyDrive/All_Datasets/Datasets_in_zip/data_with_aug.zip -d /content/drive/MyDrive/All_Datasets/Dataset_02
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (132).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1320).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1321).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1322).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1323).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1324).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1325).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1326).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1327).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1328).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1329).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (133).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1330).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1331).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1332).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1333).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1334).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1335).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1336).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1337).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1338).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1339).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (134).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1340).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1341).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1342).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1343).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1344).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1345).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1346).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1347).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1348).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1349).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (135).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1350).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1351).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1352).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1353).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1354).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1355).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1356).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1357).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1358).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1359).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (136).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1360).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1361).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1362).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1363).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1364).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1365).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1366).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1367).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1368).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1369).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (137).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1370).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1371).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1372).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1373).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1374).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1375).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1376).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1377).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1378).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1379).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (138).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1380).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1381).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1382).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1383).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1384).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1385).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1386).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1387).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1388).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1389).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (139).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1390).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1391).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1392).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1393).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1394).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1395).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1396).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1397).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1398).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1399).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (14).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (140).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1400).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1401).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1402).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1403).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1404).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1405).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1406).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1407).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1408).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1409).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (141).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1410).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1411).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1412).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1413).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1414).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1415).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1416).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1417).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1418).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1419).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (142).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1420).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1421).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1422).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1423).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1424).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1425).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1426).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1427).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1428).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1429).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (143).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1430).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1431).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1432).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1433).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1434).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1435).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1436).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1437).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1438).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1439).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (144).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1440).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1441).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1442).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1443).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1444).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1445).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1446).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1447).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1448).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1449).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (145).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1450).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1451).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1452).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1453).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1454).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1455).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1456).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1457).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1458).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1459).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (146).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1460).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1461).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1462).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1463).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1464).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1465).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1466).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1467).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1468).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1469).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (147).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1470).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1471).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1472).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1473).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1474).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1475).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1476).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1477).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1478).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1479).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (148).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1480).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1481).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1482).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1483).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1484).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1485).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1486).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1487).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1488).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1489).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (149).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1490).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1491).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1492).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1493).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1494).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1495).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1496).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1497).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1498).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1499).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (15).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (150).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1500).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1501).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1502).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1503).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1504).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1505).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1506).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1507).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1508).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1509).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (151).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1510).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1511).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1512).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1513).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1514).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1515).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1516).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1517).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1518).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1519).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (152).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1520).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1521).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1522).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1523).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1524).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1525).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1526).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1527).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1528).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1529).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (153).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1530).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1531).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1532).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1533).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1534).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1535).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1536).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1537).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1538).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1539).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (154).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1540).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1541).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1542).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1543).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1544).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1545).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1546).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1547).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1548).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1549).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (155).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1550).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1551).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1552).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1553).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1554).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1555).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1556).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1557).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1558).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1559).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (156).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1560).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1561).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1562).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1563).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1564).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1565).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1566).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1567).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1568).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1569).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (157).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1570).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1571).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1572).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1573).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1574).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1575).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1576).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1577).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1578).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1579).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (158).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (1580).JPG
# ...
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (911).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (912).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (913).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (914).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (915).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (916).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (917).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (918).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (919).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (92).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (920).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (921).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (922).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (923).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (924).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (925).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (926).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (927).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (928).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (929).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (93).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (930).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (931).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (932).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (933).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (934).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (935).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (936).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (937).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (938).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (939).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (94).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (940).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (941).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (942).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (943).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (944).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (945).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (946).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (947).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (948).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (949).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (95).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (950).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (951).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (952).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (953).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (954).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (955).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (956).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (957).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (958).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (959).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (96).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (960).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (961).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (962).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (963).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (964).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (965).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (966).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (967).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (968).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (969).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (97).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (970).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (971).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (972).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (973).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (974).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (975).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (976).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (977).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (978).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (979).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (98).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (980).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (981).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (982).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (983).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (984).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (985).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (986).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (987).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (988).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (989).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (99).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (990).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (991).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (992).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (993).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (994).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (995).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (996).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (997).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (998).JPG
#   inflating: /content/drive/MyDrive/All_Datasets/Dataset_02/Plant_leave_diseases_dataset_with_augmentation/Tomato___Tomato_Yellow_Leaf_Curl_Virus/image (999).JPG

# %%
y%load_ext nb_black

# %% [markdown]
# ### Import Dataset

# %% [markdown]
# <b> Dataset Link (Plant Vliiage Dataset ):</b><br> <a href='https://data.mendeley.com/datasets/tywbtsjrjv/1'> https://data.mendeley.com/datasets/tywbtsjrjv/1 </a>

# %%
transform = transforms.Compose(
    [transforms.Resize(255), transforms.CenterCrop(224), transforms.ToTensor()]
)

# %%
dataset = datasets.ImageFolder("./drive/MyDrive/All_Datasets/Dataset_02", transform=transform)

# %%
dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 61486
#     Root location: ./drive/MyDrive/All_Datasets/Dataset_02
#     StandardTransform
# Transform: Compose(
#                Resize(size=255, interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#            )

# %%
indices = list(range(len(dataset)))

# %%
split = int(np.floor(0.85 * len(dataset)))  # train_size

# %%
validation = int(np.floor(0.70 * split))  # validation

# %%
print(0, validation, split, len(dataset))
# Out:
# 0 36584 52263 61486

# %%
print(f"length of train size :{validation}")
print(f"length of validation size :{split - validation}")
print(f"length of test size :{len(dataset)-validation}")
# Out:
# length of train size :36584
# length of validation size :15679
# length of test size :24902

# %%
np.random.shuffle(indices)

# %% [markdown]
# ### Split into Train and Test

# %%
train_indices, validation_indices, test_indices = (
    indices[:validation],
    indices[validation:split],
    indices[split:],
)

# %%
train_sampler = SubsetRandomSampler(train_indices)
validation_sampler = SubsetRandomSampler(validation_indices)
test_sampler = SubsetRandomSampler(test_indices)

# %%
targets_size = len(dataset.class_to_idx)
print(targets_size)
# Out:
# 39

# %% [markdown]
# ### Model

# %% [markdown]
# <b>Convolution Aithmetic Equation : </b>(W - F + 2P) / S + 1 <br>
# W = Input Size<br>
# F = Filter Size<br>
# P = Padding Size<br>
# S = Stride <br>

# %% [markdown]
# ### Transfer Learning

# %%
# model = models.vgg16(pretrained=True)

# %%
# for params in model.parameters():
#     params.requires_grad = False

# %%
# model

# %%
# n_features = model.classifier[0].in_features
# n_features

# %%
# model.classifier = nn.Sequential(
#     nn.Linear(n_features, 1024),
#     nn.ReLU(),
#     nn.Dropout(0.4),
#     nn.Linear(1024, targets_size),
# )

# %%
# model

# %% [markdown]
# ### Original Modeling

# %%
class CNN(nn.Module):
    def __init__(self, K):
        super(CNN, self).__init__()
        self.conv_layers = nn.Sequential(
            # conv1
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),
            # conv2
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),
            # conv3
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2),
            # conv4
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2),
        )

        self.dense_layers = nn.Sequential(
            nn.Dropout(0.4),
            nn.Linear(50176, 1024),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(1024, K),
        )

    def forward(self, X):
        out = self.conv_layers(X)

        # Flatten
        out = out.view(-1, 50176)

        # Fully connected
        out = self.dense_layers(out)

        return out

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
print(device) # = "cpu"
# Out:
# cpu

# %%
model = CNN(targets_size)

# %%
model.to(device)
# Out:
# CNN(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU()
#     (16): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU()
#     (19): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (21): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU()
#     (23): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (24): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU()
#     (26): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense_layers): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=50176, out_features=1024, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=1024, out_features=39, bias=True)
#   )
# )

# %%
from torchsummary import summary

summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 224, 224]             896
#               ReLU-2         [-1, 32, 224, 224]               0
#        BatchNorm2d-3         [-1, 32, 224, 224]              64
#             Conv2d-4         [-1, 32, 224, 224]           9,248
#               ReLU-5         [-1, 32, 224, 224]               0
#        BatchNorm2d-6         [-1, 32, 224, 224]              64
#          MaxPool2d-7         [-1, 32, 112, 112]               0
#             Conv2d-8         [-1, 64, 112, 112]          18,496
#               ReLU-9         [-1, 64, 112, 112]               0
#       BatchNorm2d-10         [-1, 64, 112, 112]             128
#            Conv2d-11         [-1, 64, 112, 112]          36,928
#              ReLU-12         [-1, 64, 112, 112]               0
#       BatchNorm2d-13         [-1, 64, 112, 112]             128
#         MaxPool2d-14           [-1, 64, 56, 56]               0
#            Conv2d-15          [-1, 128, 56, 56]          73,856
#              ReLU-16          [-1, 128, 56, 56]               0
#       BatchNorm2d-17          [-1, 128, 56, 56]             256
#            Conv2d-18          [-1, 128, 56, 56]         147,584
#              ReLU-19          [-1, 128, 56, 56]               0
#       BatchNorm2d-20          [-1, 128, 56, 56]             256
#         MaxPool2d-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 256, 28, 28]         295,168
#              ReLU-23          [-1, 256, 28, 28]               0
#       BatchNorm2d-24          [-1, 256, 28, 28]             512
#            Conv2d-25          [-1, 256, 28, 28]         590,080
#              ReLU-26          [-1, 256, 28, 28]               0
#       BatchNorm2d-27          [-1, 256, 28, 28]             512
#         MaxPool2d-28          [-1, 256, 14, 14]               0
#           Dropout-29                [-1, 50176]               0
#            Linear-30                 [-1, 1024]      51,381,248
#              ReLU-31                 [-1, 1024]               0
#           Dropout-32                 [-1, 1024]               0
#            Linear-33                   [-1, 39]          39,975
# ================================================================
# Total params: 52,595,399
# Trainable params: 52,595,399
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 143.96
# Params size (MB): 200.64
# Estimated Total Size (MB): 345.17
# ----------------------------------------------------------------

# %%
criterion = nn.CrossEntropyLoss()  # this include softmax + cross entropy loss
optimizer = torch.optim.Adam(model.parameters())

# %% [markdown]
# ### Batch Gradient Descent

# %%
def batch_gd(model, criterion, train_loader, test_laoder, epochs):
    train_losses = np.zeros(epochs)
    validation_losses = np.zeros(epochs)

    for e in range(epochs):
        t0 = datetime.now()
        train_loss = []
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()

            output = model(inputs)

            loss = criterion(output, targets)

            train_loss.append(loss.item())  # torch to numpy world

            loss.backward()
            optimizer.step()

        train_loss = np.mean(train_loss)

        validation_loss = []

        for inputs, targets in validation_loader:

            inputs, targets = inputs.to(device), targets.to(device)

            output = model(inputs)

            loss = criterion(output, targets)

            validation_loss.append(loss.item())  # torch to numpy world

        validation_loss = np.mean(validation_loss)

        train_losses[e] = train_loss
        validation_losses[e] = validation_loss

        dt = datetime.now() - t0

        print(
            f"Epoch : {e+1}/{epochs} Train_loss:{train_loss:.3f} Test_loss:{validation_loss:.3f} Duration:{dt}"
        )

    return train_losses, validation_losses

# %%
batch_size = 64
train_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=train_sampler
)
test_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=test_sampler
)
validation_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=validation_sampler
)

# %%
train_losses, validation_losses = batch_gd(
    model, criterion, train_loader, validation_loader, 5
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-9ca029ce44ab> in <cell line: 0>()
# ----> 1 train_losses, validation_losses = batch_gd(
#       2     model, criterion, train_loader, validation_loader, 5
#       3 )
#
# <ipython-input-57-01b32ce61c3f> in batch_gd(model, criterion, train_loader, test_laoder, epochs)
#      11             optimizer.zero_grad()
#      12
# ---> 13             output = model(inputs)
#      14
#      15             loss = criterion(output, targets)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-50-a745e6b1e71c> in forward(self, X)
#      46
#      47     def forward(self, X):
# ---> 48         out = self.conv_layers(X)
#      49
#      50         # Flatten
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/pooling.py in forward(self, input)
#     211
#     212     def forward(self, input: Tensor):
# --> 213         return F.max_pool2d(
#     214             input,
#     215             self.kernel_size,
#
# /usr/local/lib/python3.11/dist-packages/torch/_jit_internal.py in fn(*args, **kwargs)
#     622             return if_true(*args, **kwargs)
#     623         else:
# --> 624             return if_false(*args, **kwargs)
#     625
#     626     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     828     if stride is None:
#     829         stride = torch.jit.annotate(List[int], [])
# --> 830     return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#     831
#     832
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save the Model

# %%
torch.save(model.state_dict() , '/content/drive/MyDrive/Plant-Disease/plant_disease_model_1.pt')

# %% [markdown]
# ### Load Model

# %%
# targets_size = 39
print(device)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Initialize the model
model = CNN(targets_size)

# Load the state dictionary
model.load_state_dict(torch.load("/content/drive/MyDrive/Plant-Disease/plant_disease_model_1.pt", map_location=device))

# Move the entire model to the correct device
model = model.to(device)

# Verify the device of each parameter
model.eval()
for name, param in model.named_parameters():
    print(f"{name} is on {param.device}")
# Out:
# cuda
# cuda
# <ipython-input-58-488cdba4f7f0>:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/content/drive/MyDrive/Plant-Disease/plant_disease_model_1.pt", map_location=device))
# conv_layers.0.weight is on cuda:0
# conv_layers.0.bias is on cuda:0
# conv_layers.2.weight is on cuda:0
# conv_layers.2.bias is on cuda:0
# conv_layers.3.weight is on cuda:0
# conv_layers.3.bias is on cuda:0
# conv_layers.5.weight is on cuda:0
# conv_layers.5.bias is on cuda:0
# conv_layers.7.weight is on cuda:0
# conv_layers.7.bias is on cuda:0
# conv_layers.9.weight is on cuda:0
# conv_layers.9.bias is on cuda:0
# conv_layers.10.weight is on cuda:0
# conv_layers.10.bias is on cuda:0
# conv_layers.12.weight is on cuda:0
# conv_layers.12.bias is on cuda:0
# conv_layers.14.weight is on cuda:0
# conv_layers.14.bias is on cuda:0
# conv_layers.16.weight is on cuda:0
# conv_layers.16.bias is on cuda:0
# conv_layers.17.weight is on cuda:0
# conv_layers.17.bias is on cuda:0
# conv_layers.19.weight is on cuda:0
# conv_layers.19.bias is on cuda:0
# conv_layers.21.weight is on cuda:0
# conv_layers.21.bias is on cuda:0
# conv_layers.23.weight is on cuda:0
# conv_layers.23.bias is on cuda:0
# conv_layers.24.weight is on cuda:0
# conv_layers.24.bias is on cuda:0
# conv_layers.26.weight is on cuda:0
# conv_layers.26.bias is on cuda:0
# dense_layers.1.weight is on cuda:0
# dense_layers.1.bias is on cuda:0
# dense_layers.4.weight is on cuda:0
# dense_layers.4.bias is on cuda:0

# %%
# %matplotlib notebook

# %% [markdown]
# ### Plot the loss

# %%
plt.plot(train_losses , label = 'train_loss')
plt.plot(validation_losses , label = 'validation_loss')
plt.xlabel('No of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Accuracy

# %%
print(device)

def accuracy(loader):
    n_correct = 0
    n_total = 0

    for inputs, targets in loader:
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = model(inputs)

        _, predictions = torch.max(outputs, 1)

        n_correct += (predictions == targets).sum().item()
        n_total += targets.shape[0]

    acc = n_correct / n_total
    return acc
# Out:
# cuda

# %%
train_acc = accuracy(train_loader)
test_acc = accuracy(test_loader)
validation_acc = accuracy(validation_loader)

# %%
print(
    f"Train Accuracy : {train_acc}\nTest Accuracy : {test_acc}\nValidation Accuracy : {validation_acc}"
)
# Out:
# Train Accuracy : 96.7
# Test Accuracy : 98.9
# Validation Accuracy : 98.7

# %% [markdown]
# ### Single Image Prediction

# %%
transform_index_to_disease = dataset.class_to_idx

# %%
transform_index_to_disease = dict(
    [(value, key) for key, value in transform_index_to_disease.items()]
)  # reverse the index

# %%
data = pd.read_csv("disease_info.csv", encoding="cp1252")

# %%
from PIL import Image
import torchvision.transforms.functional as TF

# %%
def single_prediction(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))
    input_data = TF.to_tensor(image)
    input_data = input_data.view((-1, 3, 224, 224))
    output = model(input_data)
    output = output.detach().numpy()
    index = np.argmax(output)
    print("Original : ", image_path[12:-4])
    pred_csv = data["disease_name"][index]
    print(pred_csv)

# %%
single_prediction("test_images/Apple_ceder_apple_rust.JPG")
# Out:
# Original :  Apple_ceder_apple_rust
# Apple : Cedar rust

# %% [markdown]
# ### Wrong Prediction

# %%
single_prediction("test_images/Apple_scab.JPG")
# Out:
# Original :  Apple_scab
# Tomato : Septoria Leaf Spot

# %%
single_prediction("test_images/Grape_esca.JPG")
# Out:
# Original :  Grape_esca
# Grape : Esca | Black Measles

# %%
single_prediction("test_images/apple_black_rot.JPG")
# Out:
# Original :  apple_black_rot
# Pepper bell : Healthy

# %%
single_prediction("test_images/apple_healthy.JPG")
# Out:
# Original :  apple_healthy
# Apple : Healthy

# %%
single_prediction("test_images/background_without_leaves.jpg")
# Out:
# Original :  background_without_leaves
# Background Without Leaves

# %%
single_prediction("test_images/blueberry_healthy.JPG")
# Out:
# Original :  blueberry_healthy
# Blueberry : Healthy

# %%
single_prediction("test_images/cherry_healthy.JPG")
# Out:
# Original :  cherry_healthy
# Cherry : Healthy

# %%
single_prediction("test_images/cherry_powdery_mildew.JPG")
# Out:
# Original :  cherry_powdery_mildew
# Cherry : Powdery Mildew

# %%
single_prediction("test_images/corn_cercospora_leaf.JPG")
# Out:
# Original :  corn_cercospora_leaf
# Corn : Cercospora Leaf Spot | Gray Leaf Spot

# %%
single_prediction("test_images/corn_common_rust.JPG")
# Out:
# Original :  corn_common_rust
# Corn : Common Rust

# %%
single_prediction("test_images/corn_healthy.jpg")
# Out:
# Original :  corn_healthy
# Corn : Healthy

# %%
single_prediction("test_images/corn_northen_leaf_blight.JPG")
# Out:
# Original :  corn_northen_leaf_blight
# Corn : Northern Leaf Blight

# %%
single_prediction("test_images/grape_black_rot.JPG")
# Out:
# Original :  grape_black_rot
# Grape : Black Rot

# %%
single_prediction("test_images/grape_healthy.JPG")
# Out:
# Original :  grape_healthy
# Grape : Healthy

# %%
single_prediction("test_images/grape_leaf_blight.JPG")
# Out:
# Original :  grape_leaf_blight
# Grape : Leaf Blight | Isariopsis Leaf Spot

# %%
single_prediction("test_images/orange_haunglongbing.JPG")
# Out:
# Original :  orange_haunglongbing
# Orange : Haunglongbing | Citrus Greening

# %%
single_prediction("test_images/peach_bacterial_spot.JPG")
# Out:
# Original :  peach_bacterial_spot
# Peach : Bacterial Spot

# %%
single_prediction("test_images/peach_healthy.JPG")
# Out:
# Original :  peach_healthy
# Peach : Healthy

# %%
single_prediction("test_images/pepper_bacterial_spot.JPG")
# Out:
# Original :  pepper_bacterial_spot
# Pepper bell : Healthy

# %%
single_prediction("test_images/pepper_bell_healthy.JPG")
# Out:
# Original :  pepper_bell_healthy
# Pepper bell : Healthy

# %%
single_prediction("test_images/potato_early_blight.JPG")
# Out:
# Original :  potato_early_blight
# Potato : Early Blight

# %%
single_prediction("test_images/potato_healthy.JPG")
# Out:
# Original :  potato_healthy
# Potato : Healthy

# %%
single_prediction("test_images/potato_late_blight.JPG")
# Out:
# Original :  potato_late_blight
# Potato : Late Blight

# %%
single_prediction("test_images/raspberry_healthy.JPG")
# Out:
# Original :  raspberry_healthy
# Raspberry : Healthy

# %%
single_prediction("test_images/soyaben healthy.JPG")
# Out:
# Original :  soyaben healthy
# Soybean : Healthy

# %%
single_prediction("test_images/potato_late_blight.JPG")
# Out:
# Original :  potato_late_blight
# Potato : Late Blight

# %%
single_prediction("test_images/squash_powdery_mildew.JPG")
# Out:
# Original :  squash_powdery_mildew
# Squash : Powdery Mildew

# %%
single_prediction("test_images/starwberry_healthy.JPG")
# Out:
# Original :  starwberry_healthy
# Strawberry : Healthy

# %%
single_prediction("test_images/starwberry_leaf_scorch.JPG")
# Out:
# Original :  starwberry_leaf_scorch
# Strawberry : Leaf Scorch

# %%
single_prediction("test_images/tomato_bacterial_spot.JPG")
# Out:
# Original :  tomato_bacterial_spot
# Tomato : Early Blight

# %%
single_prediction("test_images/tomato_early_blight.JPG")
# Out:
# Original :  tomato_early_blight
# Tomato : Early Blight

# %%
single_prediction("test_images/tomato_healthy.JPG")
# Out:
# Original :  tomato_healthy
# Tomato : Healthy

# %%
single_prediction("test_images/tomato_late_blight.JPG")
# Out:
# Original :  tomato_late_blight
# Tomato : Late Blight

# %%
single_prediction("test_images/tomato_leaf_mold.JPG")
# Out:
# Original :  tomato_leaf_mold
# Tomato : Leaf Mold

# %%
single_prediction("test_images/tomato_mosaic_virus.JPG")
# Out:
# Original :  tomato_mosaic_virus
# Tomato : Mosaic Virus

# %%
single_prediction("test_images/tomato_septoria_leaf_spot.JPG")
# Out:
# Original :  tomato_septoria_leaf_spot
# Tomato : Septoria Leaf Spot

# %%
single_prediction("test_images/tomato_spider_mites_two_spotted_spider_mites.JPG")
# Out:
# Original :  tomato_spider_mites_two_spotted_spider_mites
# Tomato : Spider Mites | Two-Spotted Spider Mite

# %%
single_prediction("test_images/tomato_target_spot.JPG")
# Out:
# Original :  tomato_target_spot
# Tomato : Target Spot

# %%
single_prediction("test_images/tomato_yellow_leaf_curl_virus.JPG")
# Out:
# Original :  tomato_yellow_leaf_curl_virus
# Tomato : Yellow Leaf Curl Virus
